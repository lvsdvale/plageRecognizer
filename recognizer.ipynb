# %%
import os
import json

# %%
with open('map_plant_plage.json', 'r') as file:
    plants_plagues_map = json.load(file)

# %%
plants_plagues_map
# Out:
# {'Abacaxi (Pineapple)': {'Broca (Pineapple Fruit Borer)': 0,
#   'Fusariose (Fusariose)': 1,
#   'Podridão (Black Rot)': 2},
#  'Algodão (Cotton)': {'Fusariose (Fusarium Wilt)': 0,
#   'Mancha de Mirotecio (Myrothecium leaf spot)': 1,
#   'Mela (Soreshin)': 2,
#   'Ramularia (Areolate Mildew)': 3},
#  'Arroz (Rice)': {'Brusone (Rice Blast)': 0, 'Escaldadura (Leaf Scald)': 1},
#  'Café (Coffee)': {'BichoMineiro (Leaf Miner)': 0,
#   'Cercospora-Ferrugem (Cercospora Leaf Spot and Rust)': 1,
#   'Cercosporiose (Cercospora Leaf Spot)': 2,
#   'Ferrugem (Rust)': 3,
#   'Mancha Aureolada (Bacterial Blight)': 4,
#   'Mancha Mantegosa (Blister Spot)': 5,
#   'Phoma (Brown leaf spot)': 6,
#   'QueimaFio (Pellicularia koleroga)': 7,
#   'Rizoctoniose (Damping Off)': 8,
#   'Saudavel (Healthy)': 9},
#  'Cajueiro (Cashew Tree)': {'Alga (Algae)': 0,
#   'Antracnose (Anthracnose)': 1,
#   'Larva (Worm)': 2,
#   'Mancha Angular (Angular Leaf Spot)': 3,
#   'Mofo Preto (Black Mould)': 4,
# ...
